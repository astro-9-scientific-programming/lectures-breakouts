# %% [markdown]
# ## Breakout Session
#
# ### Plot before you integrate...
#
# 1) Try to integrate the following function using a simple rectangle rule...
#
# $$ y(x) = sin(1/x)$$

# %%
def integral(func,x_0 = 0, x_1=1,N=100):
    x = np.linspace(x_0,x_1,N) #grid of x values
    dx = x[1]-x[0] #difference between x values


    integral = np.sum(func(x))*dx
    return integral

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = np.linspace(0,.11,10000)
plt.plot(x,np.sin(1/x))
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in true_divide
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in sin

# %% [markdown]
# 2) Now try to use scipy integrate. Notice that you will get an warning... why?

# %%
def f(x):
    return x/(x-0.5)

# %%
from scipy import integrate

integrate.quad(f,0,1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-25-61d564d4853c> in <module>
#       1 from scipy import integrate
#       2
# ----> 3 integrate.quad(f,0,1)
#
# /usr/local/lib/python3.7/site-packages/scipy-1.3.0-py3.7-macosx-10.14-x86_64.egg/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     339     if weight is None:
#     340         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 341                        points)
#     342     else:
#     343         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# /usr/local/lib/python3.7/site-packages/scipy-1.3.0-py3.7-macosx-10.14-x86_64.egg/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     446     if points is None:
#     447         if infbounds == 0:
# --> 448             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     449         else:
#     450             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# <ipython-input-24-66851fee8a1c> in f(x)
#       1 def f(x):
# ----> 2     return x/(x-0.5)
#
# ZeroDivisionError: float division by zero

# %% [markdown]
# ### Differential Equation Solving
#
# 1) Try solving the following differential equation using odeint in scipy,
#
# $$\frac{dy}{dt} = − exp(−t)(10 sin(10t) + cos(10t))$$
#
# with initial value
#
# $y(1)=1$.

# %% [markdown]
# 2) plot the solution between 0 and 10.

# %%
from scipy.integrate import odeint #ordinary differential equation integrator

def f(y,t):
    t3 = t-1
    return -np.exp(-t3)*(10*np.sin(10*t3)+cos(10*t3))

# %%
y0 = 1
xmin = 0
xmax = 10

t = np.arange(xmin,xmax,.01)

# %%
y = odeint(f,y0,t)

# %%
# %pylab inline
plt.plot(t,y)
plt.plot([1],[1],"x")
# Out:
# Populating the interactive namespace from numpy and matplotlib
